# %%
import requests
import json
import urllib

# %%
import pandas as pd
import io
import geopy

# %%
from geopy.geocoders import Nominatim, GoogleV3

# %%
base_url= "https://maps.googleapis.com/maps/api/geocode/json?"
AUTH_KEY = 'AIzaSyBCToJK3ucEZ6EMBdgX0pD-xdvNBTlrYCM'

# %%
geolocator = Nominatim(user_agent='janderson5417@gmail.com')

# %%
geolocator=GoogleV3(api_key=AUTH_KEY)

# %%
locs = pd.read_csv('partner_events.csv', header=1)

# %%
locs
# Out:
#                 NGO                  Theme      Date  \
# 0        CityPlants                  Trees   12/4/21
# 1        CityPlants                  Trees  12/11/21
# 2        CityPlants                  Trees  12/18/21
# 3        CityPlants                  Trees   11/6/21
# 4        CityPlants                  Trees  11/13/21
# 5        CityPlants                  Trees  11/13/21
# 6        CityPlants                  Trees  11/13/21
# 7        CityPlants                  Trees  11/13/21
# 8        CityPlants                  Trees  11/13/21
# 9        CityPlants                  Trees  11/20/21
# 10       CityPlants                  Trees       NaN
# 11  Climate Resolve      Advocacy & Policy       NaN
# 12      CropSwap LA              Food/Soil       NaN
# 13  Kiss the Ground              Food/Soil       NaN
# 14             KYCC                  Trees   12/4/21
# 15             KYCC                  Trees  11/21/21
# 16             KYCC  Social & Env Services       NaN
# ...

# %%
locs['geo'] = locs['Address'].apply(geolocator.geocode)

# %%
locs["point"]= locs["geo"].apply(lambda geo: tuple(geo.point) if geo else None)

# %%
locs[['lat', 'lon', 'altitude']] = pd.DataFrame(locs['point'].to_list(), index=locs.index)

# %%
locs
# Out:
#                 NGO                  Theme      Date  \
# 0        CityPlants                  Trees   12/4/21
# 1        CityPlants                  Trees  12/11/21
# 2        CityPlants                  Trees  12/18/21
# 3        CityPlants                  Trees   11/6/21
# 4        CityPlants                  Trees  11/13/21
# 5        CityPlants                  Trees  11/13/21
# 6        CityPlants                  Trees  11/13/21
# 7        CityPlants                  Trees  11/13/21
# 8        CityPlants                  Trees  11/13/21
# 9        CityPlants                  Trees  11/20/21
# 10       CityPlants                  Trees       NaN
# 11  Climate Resolve      Advocacy & Policy       NaN
# 12      CropSwap LA              Food/Soil       NaN
# 13  Kiss the Ground              Food/Soil       NaN
# 14             KYCC                  Trees   12/4/21
# 15             KYCC                  Trees  11/21/21
# 16             KYCC  Social & Env Services       NaN
# ...

# %%
locs.to_csv(r'/Users/Jen/GitHub/earthgrids_v2/NGO_locs-geocode.csv', index = False)
